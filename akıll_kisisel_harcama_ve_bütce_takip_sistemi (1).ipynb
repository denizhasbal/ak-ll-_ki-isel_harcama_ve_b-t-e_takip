# %%
ad = input("adınızı girin:")
# Out:
# adınızı girin: Deniz

# %%
aylikbutce= input("aylık bütçenizi girin:")
butce=float(aylikbutce)
# Out:
# aylık bütçenizi girin: 30000

# %%
gelirler=[]
giderler=[]
kategoriler=set()

# %%
gelir_aciklamasi=input("gelir açıklamasını girin:")
# Out:
# gelir açıklamasını girin: Maaş

# %%
gelir_miktari= input("gelir miktarını girin:")
miktar=float(gelir_miktari)
# Out:
# gelir miktarını girin: 25000

# %%
gelirler.append({"aciklama":"Maaş","miktar":25000})

# %%
gelir_aciklaması=input("gelir açıklamasını girin:")
# Out:
# gelir açıklamasını girin: Burs

# %%
gelir_miktarı=input("gelir miktarını girin:")
# Out:
# gelir miktarını girin: 5000

# %%
gelirler.append({"aciklama":"Burs","miktar":5000})

# %%
gider_aciklaması = input ("gider açıklamasını girin:")
# Out:
# gider açıklamasını girin: Kurs

# %%
kategori=input("kategori girin:")
# Out:
# kategori girin: Egitim

# %%
miktar=input("gider miktarını bulun:")
# Out:
# gider miktarını bulun: 3500

# %%
giderler.append({"aciklama":"Kurs","Kategori":"Egitim","miktar":3500 })

# %%
hepsi=gelirler+giderler

# %%
for eleman in hepsi:
    print(eleman)
# Out:
# {'aciklama': 'Maaş', 'miktar': 25000}
# {'aciklama': 'Burs', 'miktar': 5000}
# {'aciklama': 'Kurs', 'Kategori': 'Egitim', 'miktar': 3500}

# %%
for e in hepsi:
    print(e)
# Out:
# {'aciklama': 'Maaş', 'miktar': 25000}
# {'aciklama': 'Burs', 'miktar': 5000}
# {'aciklama': 'Kurs', 'Kategori': 'Egitim', 'miktar': 3500}

# %%
for e in hepsi:
    print (e["aciklama"],e["miktar"])
# Out:
# Maaş 25000
# Burs 5000
# Kurs 3500

# %%
def toplam_gelir_hesapla():
    t=0
    for x in gelirler:
        t=t+x["miktar"]
    return t

# %%
def toplam_gider_hesapla():
    t=0
    for x in giderler:
        t=t+x["miktar"]
    return t

# %%
gelir=toplam_gelir_hesapla()
gider=toplam_gider_hesapla()

# %%
kalan=gelir-gider
print("kalan bütçe:",kalan)
# Out:
# kalan bütçe: 26500

# %%
if kalan<0:
    print("bütçeni aştın.")
elif kalan ==0:
    print("kritik seviye.")
else:
    print("harika gidiyorsun.")
# Out:
# harika gidiyorsun.

# %%
en_yuksek=giderler[0]["miktar"]
en_dusuk=giderler[0]["miktar"]

# %%
for g in giderler:
    if g["miktar"]>en_yuksek:
        en_yuksek=g["miktar"]
    if g["miktar"]<en_dusuk:
        en_dusuk=g["miktar"]

# %%
print(en_yuksek,en_dusuk)
# Out:
# 3500 3500

# %%
aranan=input("aranacak kelime:")
for g in giderler:
    if aranan in g ["aciklama"]:
        print("bulundu:",g["aciklama"],g["miktar"])
# Out:
# aranacak kelime: egitim

# %%
toplam_gider = 0
for g in giderler:
    toplam_gider = toplam_gider + g["miktar"]

print("--- AYLIK HARCAMA RAPORU ---")
print("Toplam işlem:", len(giderler))
print("Toplam gider:", toplam_gider)
print("Ortalama gider:", toplam_gider / len(giderler))
print("En yüksek gider:", en_yuksek)
print("En düşük gider:", en_dusuk)
# Out:
# --- AYLIK HARCAMA RAPORU ---
# Toplam işlem: 1
# Toplam gider: 3500
# Ortalama gider: 3500.0
# En yüksek gider: 3500
# En düşük gider: 3500

# %%
import random
tavsiyeler=[
    "Kurs fiyatlarını araştır"
]

# %%
print(random.choice(tavsiyeler))
# Out:
# Kurs fiyatlarını araştır

# %%
def rapor_yazdir(*args):
    for bilgi in args:
        print(bilgi)

# %%
def rapor_yazdir(*args):
    print(" AYLIK FİNANS RAPORU ")
    print()
    print("Kullanıcı:", args[0])
    print("Başlangıç Bütçesi:", args[1], "TL")
    print("Toplam Gelir:", args[2], "TL")
    print("Toplam Gider:", args[3], "TL")
    print("Kalan Para:", args[4], "TL")
    print("Toplam Harcama Sayısı:", args[5])
    print("Ortalama Harcama:", args[6], "TL")
    print("Tasarruf Durumu:", args[7])

# %%
rapor_yazdir("Deniz", 20000, 45000, toplam_gider, 32500, len(giderler), toplam_gider / len(giderler), "İyi")
# Out:
# ========== AYLIK FİNANS RAPORU ==========
#
# Kullanıcı: Deniz
# Başlangıç Bütçesi: 20000 TL
# Toplam Gelir: 45000 TL
# Toplam Gider: 3500 TL
# Kalan Para: 32500 TL
#
# Toplam Harcama Sayısı: 1
# Ortalama Harcama: 3500.0 TL
# Tasarruf Durumu: İyi
# ...
